# %%
import duckdb

con = duckdb.connect("data/output.duckdb")

df = con.execute("""
    SELECT * FROM output.github_data.github_repos LIMIT 5;
""").fetchdf()

print(df)
# Out:
#                     name                     full_name  stars  forks  \
# 0  accumulo-fluo-recipes  apache/accumulo-fluo-recipes     18     21
# 1  accumulo-maven-plugin  apache/accumulo-maven-plugin      5      9
# 2       accumulo-website       apache/accumulo-website     17    105
# 3       activemq-artemis       apache/activemq-artemis    993    940
# 4            age-website            apache/age-website     37     67
#
#               license language                created_at  \
# 0  Apache License 2.0     Java 2015-09-04 03:24:21+02:00
# 1  Apache License 2.0    Shell 2018-10-09 16:51:13+02:00
# 2             unknown     HTML 2016-11-28 09:00:07+01:00
# 3  Apache License 2.0     Java 2015-05-22 09:00:05+02:00
# 4             unknown     HTML 2020-07-01 08:20:58+02:00
#
#                  updated_at                 pushed_at  created_at_is_invalid  \
# 0 2025-07-14 14:10:43+02:00 2025-02-13 21:01:58+01:00                  False
# ...
