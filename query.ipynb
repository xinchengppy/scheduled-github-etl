# %%
import duckdb

con = duckdb.connect("data/output.duckdb")

df = con.execute("""
    SELECT * FROM output.github_data.github_repos LIMIT 5;
""").fetchdf()

print(df)

df_2 = con.execute("""
    SELECT count(*) FROM output.github_data.github_repos;
""").fetchdf()
print(df_2)
# Out:
#                      name                      full_name  stars  forks  \
# 0                activemq                apache/activemq   2404   1476
# 1        activemq-website        apache/activemq-website     23     59
# 2  airavata-django-portal  apache/airavata-django-portal     36     48
# 3                     apr                     apache/apr    513    215
# 4            arrow-dotnet            apache/arrow-dotnet     17      9
#
#               license language                created_at  \
# 0  Apache License 2.0     Java 2009-05-21 03:33:45+02:00
# 1             unknown     HTML 2018-10-10 00:53:50+02:00
# 2  Apache License 2.0   Python 2017-09-02 09:00:08+02:00
# 3  Apache License 2.0        C 2009-03-27 16:41:55+01:00
# 4  Apache License 2.0       C# 2025-03-31 04:45:50+02:00
#
#                  updated_at                 pushed_at  created_at_is_invalid  \
# 0 2025-10-30 06:14:15+01:00 2025-10-19 18:26:23+02:00                  False
# ...
